# %% [markdown]
# # United Nations Parallel Corpora Analysis using SpaCy and Camel
# ### Kinan Al-Mouk / kim47@pitt.edu / April 3rd 2022

# %% [markdown]
# ## Table of Contents
# [`Imports`](#Importing-Tools)
#
# [`Uploading and Analyzing Data`](##Uploading-and-Analyzing-Data-using-Spacy)
#
#    - [`English`](#English)
#    - [`Spanish`](#Spanish)
#    - [`French`](#French)
#    - [`Russian`](#Russian)
#    - [`Chinese`](#Chinese)
#    - [`Arabic`](#Arabic)

# %% [markdown]
# # Importing Tools

# %%
import spacy

# %% [markdown]
# I am using [SpaCy](https://spacy.io/) for NLP of **English, Spanish, French, Russian**, and **Mandarin Chinese** in order to ensure that the tokenization for each langauge remains accurate since NLTK is mostly and primarily used for English language NLP.
#
# However there is no [SpaCy](https://spacy.io/) module that can allow me to process the **Arabic** files. At the moment I am still looking into other resources.

# %%
# Still Importing NLTK just incase
import nltk 
import pickle
from time import time
import numpy as np 
import pandas as pd

# %% [markdown]
# # Uploading and Analyzing Data using Spacy

# %% [markdown]
# ## English

# %%
# Loading in English Files
start = time()
f = open('data/sixway/english.100k', 'r') # Reading in English File
english = f.read()
print("Data loaded in:", (time()-start), "seconds.")
f.close()

# Creating Smaller Slice to Analyze using SpaCy
english_samp = english100[:1000]
# Out:
# Data loaded in: 0.17308807373046875 seconds.

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(english_samp)
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# RESOLUTION 918 (1994)
# Adopted by the Security Council at its 3377th meeting, on 17 May 1994
# The Security Council,
# Reaffirming all its previous resolutions on the situation in Rwanda, in particular its resolution 872 (1993) of 5 October 1993 by which it established the United Nations Assistance Mission for Rwanda (UNAMIR), its resolution 909 (1994) of 5 April 1994 which extended the mandate of UNAMIR until 29 July 1994, and its resolution 912 (1994) of 21 April 1994 by which it adjusted the mandate of UNAMIR,
# Recalling the statements made by the President of the Council on 7 April 1994 (S/PRST/1994/16) and 30 April 1994 (S/PRST/1994/21),
# Having considered the report of the Secretary-General dated 13 May 1994 (S/1994/565),
# Reaffirming its resolution 868 (1993) of 29 September 1993 on the security of United Nations operations,
# Strongly condemning the ongoing violence in Rwanda and particularly condemning the very numerous killings of civilians which have taken place in Rwanda and the impu
# RESOLUTION PROPN ROOT
# 918 NUM nummod
# ( PUNCT punct
# 1994 NUM npadvmod
# ) PUNCT punct
#
#  SPACE dep
# Adopted VERB acl
# by ADP agent
# the DET det
# Security PROPN compound
# Council PROPN pobj
# at ADP prep
# its PRON poss
# 3377th ADJ amod
# meeting NOUN pobj
# , PUNCT punct
# on ADP prep
# 17 NUM nummod
# May PROPN pobj
# 1994 NUM nummod
#
#  SPACE dep
# The DET det
# Security PROPN compound
# Council PROPN appos
# , PUNCT punct
#
#  SPACE dep
# Reaffirming VERB appos
# all DET predet
# its PRON poss
# previous ADJ amod
# resolutions NOUN dobj
# on ADP prep
# the DET det
# situation NOUN pobj
# in ADP prep
# Rwanda PROPN pobj
# , PUNCT punct
# in ADP prep
# particular ADJ amod
# its PRON poss
# resolution NOUN dobj
# 872 NUM nummod
# ( PUNCT punct
# 1993 NUM appos
# ) PUNCT punct
# of ADP prep
# 5 NUM nummod
# October PROPN pobj
# 1993 NUM nummod
# by ADP prep
# which PRON pobj
# it PRON nsubj
# established VERB relcl
# the DET det
# United PROPN compound
# Nations PROPN compound
# Assistance PROPN compound
# Mission PROPN dobj
# for ADP prep
# Rwanda PROPN pobj
# ( PUNCT punct
# UNAMIR PROPN appos
# ) PUNCT punct
# , PUNCT punct
# its PRON poss
# resolution NOUN appos
# 909 NUM nummod
# ( PUNCT punct
# 1994 NUM appos
# ) PUNCT punct
# of ADP prep
# 5 NUM nummod
# April PROPN pobj
# 1994 NUM nummod
# which PRON nsubj
# extended VERB relcl
# the DET det
# mandate NOUN dobj
# of ADP prep
# UNAMIR PROPN pobj
# until ADP prep
# 29 NUM nummod
# July PROPN pobj
# 1994 NUM nummod
# , PUNCT punct
# and CCONJ cc
# its PRON poss
# resolution NOUN conj
# 912 NUM nummod
# ( PUNCT punct
# 1994 NUM appos
# ) PUNCT punct
# of ADP prep
# 21 NUM nummod
# April PROPN pobj
# 1994 NUM nummod
# by ADP prep
# which PRON pobj
# it PRON nsubj
# adjusted VERB relcl
# the DET det
# mandate NOUN dobj
# of ADP prep
# UNAMIR PROPN pobj
# , PUNCT punct
#
#  SPACE dep
# Recalling VERB pcomp
# the DET det
# statements NOUN dobj
# made VERB acl
# by ADP agent
# the DET det
# President PROPN pobj
# of ADP prep
# the DET det
# Council PROPN pobj
# on ADP prep
# 7 NUM nummod
# April PROPN pobj
# 1994 NUM nummod
# ( PUNCT punct
# S PROPN nmod
# / SYM punct
# PRST/1994/16 PROPN appos
# ) PUNCT punct
# and CCONJ cc
# 30 NUM nummod
# April PROPN conj
# 1994 NUM nummod
# ( PUNCT punct
# S PROPN nmod
# / SYM punct
# PRST/1994/21 PROPN appos
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE dep
# Having AUX aux
# considered VERB nsubj
# the DET det
# report NOUN oprd
# of ADP prep
# the DET det
# Secretary PROPN compound
# - PUNCT punct
# General PROPN pobj
# dated VERB acl
# 13 NUM nummod
# May PROPN npadvmod
# 1994 NUM nummod
# ( PUNCT punct
# S/1994/565 PROPN npadvmod
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE dep
# Reaffirming VERB nsubj
# its PRON poss
# resolution NOUN dobj
# 868 NUM nummod
# ( PUNCT punct
# 1993 NUM appos
# ) PUNCT punct
# of ADP prep
# 29 NUM nummod
# September PROPN pobj
# 1993 NUM nummod
# on ADP prep
# the DET det
# security NOUN pobj
# of ADP prep
# United PROPN compound
# Nations PROPN compound
# operations NOUN pobj
# , PUNCT punct
#
#  SPACE dep
# Strongly ADV advmod
# condemning VERB acl
# the DET det
# ongoing ADJ amod
# violence NOUN dobj
# in ADP prep
# Rwanda PROPN pobj
# and CCONJ cc
# particularly ADV advmod
# condemning VERB conj
# the DET det
# very ADV advmod
# numerous ADJ amod
# killings NOUN dobj
# of ADP prep
# civilians NOUN pobj
# which PRON nsubj
# have AUX aux
# taken VERB relcl
# place NOUN dobj
# in ADP prep
# Rwanda PROPN pobj
# and CCONJ cc
# the DET det
# impu NOUN conj

# %% [markdown]
# ## Spanish

# %%
# Loading in Spanish Files
start = time()
f = open('data/sixway/spanish.100k', 'r') # Reading in Spanish File
spanish100 = f.read()
print("Data loaded in:", (time()-start), "seconds.")
f.close()

# Creating Smaller Slice to Analyze using SpaCy
spanish_samp = spanish100[:1000]
# Out:
# Data loaded in: 0.23191118240356445 seconds.

# %%
nlp = spacy.load('es_core_news_sm')
doc = nlp(spanish_samp)
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# RESOLUCIÓN 918 (1994)
# Aprobada por el Consejo de Seguridad en su 3377ª sesión, celebrada el 17 de mayo de 1994
# El Consejo de Seguridad,
# Reafirmando todas sus resoluciones anteriores relativas a la situación en Rwanda, en particular su resolución 872 (1993), de 5 de octubre de 1993, por la que estableció la Misión de Asistencia de las Naciones Unidas a Rwanda (UNAMIR), su resolución 909 (1994), de 5 de abril de 1994, por la que prorrogó el mandato de la UNAMIR hasta el 29 de julio de 1994, y su resolución 912 (1994), de 21 de abril de 1994, por la que modificó el mandato de la UNAMIR,
# Recordando las declaraciones formuladas por el Presidente del Consejo el 7 de abril de 1994 (S/PRST/1994/16) y el 30 de abril de 1994 (S/PRST/1994/21),
# Habiendo examinado el informe del Secretario General de fecha 13 de mayo de 1994 (S/1994/565),
# Reafirmando su resolución 868 (1993), de 29 de septiembre de 1993, relativa a la seguridad de las operaciones de las Naciones Unidas,
# Condenando enérgicamente la
# RESOLUCIÓN PROPN nsubj
# 918 NUM nummod
# ( PUNCT punct
# 1994 NOUN appos
# ) PUNCT punct
#
#  SPACE dep
# Aprobada ADJ obj
# por ADP case
# el DET det
# Consejo PROPN obj
# de ADP case
# Seguridad PROPN flat
# en ADP case
# su DET det
# 3377ª NUM amod
# sesión NOUN obl
# , PUNCT punct
# celebrada ADJ advmod
# el DET det
# 17 NUM obl
# de ADP case
# mayo NOUN compound
# de ADP case
# 1994 NUM compound
#
#  SPACE dep
# El DET det
# Consejo PROPN obj
# de ADP case
# Seguridad PROPN flat
# , PUNCT punct
#
#  SPACE dep
# Reafirmando VERB xcomp
# todas DET det
# sus DET det
# resoluciones NOUN obj
# anteriores ADJ amod
# relativas ADJ amod
# a ADP case
# la DET det
# situación NOUN nmod
# en ADP case
# Rwanda PROPN nmod
# , PUNCT punct
# en ADP advmod
# particular NOUN fixed
# su DET det
# resolución NOUN obj
# 872 NUM appos
# ( PUNCT punct
# 1993 NOUN appos
# ) PUNCT punct
# , PUNCT punct
# de ADP case
# 5 NUM obl
# de ADP case
# octubre NOUN compound
# de ADP case
# 1993 NUM compound
# , PUNCT punct
# por ADP case
# la DET det
# que PRON obl
# estableció VERB advcl
# la DET det
# Misión PROPN nsubj
# de ADP case
# Asistencia PROPN flat
# de ADP case
# las DET det
# Naciones PROPN flat
# Unidas PROPN flat
# a ADP case
# Rwanda PROPN flat
# ( PUNCT punct
# UNAMIR PROPN flat
# ) PUNCT punct
# , PUNCT punct
# su DET det
# resolución NOUN appos
# 909 NUM appos
# ( PUNCT punct
# 1994 NOUN appos
# ) PUNCT punct
# , PUNCT punct
# de ADP case
# 5 NUM nmod
# de ADP case
# abril NOUN compound
# de ADP case
# 1994 NUM compound
# , PUNCT punct
# por ADP case
# la DET det
# que PRON obl
# prorrogó VERB advcl
# el DET det
# mandato NOUN obj
# de ADP case
# la DET det
# UNAMIR PROPN nmod
# hasta ADP case
# el DET det
# 29 NUM obl
# de ADP case
# julio NOUN compound
# de ADP case
# 1994 NUM compound
# , PUNCT punct
# y CCONJ cc
# su DET det
# resolución NOUN conj
# 912 NUM nummod
# ( PUNCT punct
# 1994 NOUN appos
# ) PUNCT punct
# , PUNCT punct
# de ADP case
# 21 NUM nmod
# de ADP case
# abril NOUN compound
# de ADP case
# 1994 NUM compound
# , PUNCT punct
# por ADP case
# la DET det
# que PRON obl
# modificó VERB acl
# el DET det
# mandato NOUN obj
# de ADP case
# la DET det
# UNAMIR PROPN nmod
# , PUNCT punct
#
#  SPACE dep
# Recordando VERB advcl
# las DET det
# declaraciones NOUN obj
# formuladas ADJ amod
# por ADP case
# el DET det
# Presidente PROPN obj
# del ADP case
# Consejo PROPN flat
# el DET det
# 7 NUM obl
# de ADP case
# abril NOUN compound
# de ADP case
# 1994 NUM compound
# ( PUNCT punct
# S NOUN appos
# / PUNCT punct
# PRST/1994/16 PROPN flat
# ) PUNCT punct
# y CCONJ cc
# el DET det
# 30 NUM conj
# de ADP case
# abril NOUN compound
# de ADP case
# 1994 NUM compound
# ( PUNCT punct
# S NOUN appos
# / PUNCT punct
# PRST/1994/21 PROPN flat
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE dep
# Habiendo AUX aux
# examinado VERB xcomp
# el DET det
# informe NOUN obj
# del ADP case
# Secretario PROPN nmod
# General PROPN flat
# de ADP case
# fecha NOUN nmod
# 13 NUM appos
# de ADP case
# mayo NOUN nmod
# de ADP case
# 1994 NUM nmod
# ( PUNCT punct
# S/1994/565 PROPN appos
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE dep
# Reafirmando VERB advcl
# su DET det
# resolución NOUN obj
# 868 NUM appos
# ( PUNCT punct
# 1993 NOUN appos
# ) PUNCT punct
# , PUNCT punct
# de ADP case
# 29 NUM obl
# de ADP case
# septiembre NOUN compound
# de ADP case
# 1993 NUM compound
# , PUNCT punct
# relativa ADJ obj
# a ADP case
# la DET det
# seguridad NOUN nmod
# de ADP case
# las DET det
# operaciones NOUN nmod
# de ADP case
# las DET det
# Naciones PROPN nmod
# Unidas PROPN flat
# , PUNCT punct
#
#  SPACE dep
# Condenando VERB advcl
# enérgicamente ADV advmod
# la DET ROOT

# %% [markdown]
# ## French

# %%
# Loading in French Files
start = time()
f = open('data/sixway/french.100k', 'r') # Reading in French File
french100 = f.read()
print("Data loaded in:", (time()-start), "seconds.")
f.close()

# Creating Smaller Slice to Analyze using SpaCy
french_samp = french100[:1000]
# Out:
# Data loaded in: 0.18862700462341309 seconds.

# %%
nlp = spacy.load('fr_core_news_sm')
doc = nlp(french_samp)
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# RESOLUTION 918 (1994)
# Adoptée par le Conseil de sécurité à sa 3377e séance, le 17 mai 1994
# Le Conseil de sécurité,
# Réaffirmant toutes ses résolutions précédentes sur la situation au Rwanda, en particulier sa résolution 872 (1993) du 5 octobre 1993 portant création de la Mission des Nations Unies pour l'assistance au Rwanda (MINUAR), sa résolution 909 (1994) du 5 avril 1994, par laquelle il a prorogé le mandat de la MINUAR jusqu'au 29 juillet 1994 et sa résolution 912 (1994) du 21 avril 1994 par laquelle il a modifié le mandat de la MINUAR,
# Rappelant les déclarations faites par le Président du Conseil le 7 avril 1994 (S/PRST/1994/16) et le 30 avril 1994 (S/PRST/1994/21),
# Ayant examiné le rapport du Secrétaire général en date du 13 mai 1994 (S/1994/565),
# Réaffirmant sa résolution 868 (1993) du 29 septembre 1993 sur la sécurité des opérations des Nations Unies,
# Condamnant vigoureusement les violences en cours au Rwanda et réprouvant en particulier les très nombreux massacres de civils qui
# RESOLUTION NOUN ROOT
# 918 NUM nummod
# ( PUNCT punct
# 1994 NUM nummod
# ) PUNCT punct
#
#  SPACE dep
# Adoptée VERB ROOT
# par ADP case
# le DET det
# Conseil NOUN ROOT
# de ADP case
# sécurité NOUN nmod
# à ADP case
# sa DET det
# 3377e NUM amod
# séance NOUN nmod
# , PUNCT punct
# le DET det
# 17 NUM nmod
# mai NOUN nmod
# 1994 NUM nmod
#
#  SPACE dep
# Le DET det
# Conseil NOUN obj
# de ADP case
# sécurité NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Réaffirmant PROPN flat:name
# toutes ADJ amod
# ses DET det
# résolutions NOUN obj
# précédentes ADJ amod
# sur ADP case
# la DET det
# situation NOUN nmod
# au ADP case
# Rwanda PROPN nmod
# , PUNCT punct
# en ADP advmod
# particulier ADJ fixed
# sa DET det
# résolution NOUN nmod
# 872 NUM nummod
# ( PUNCT punct
# 1993 NUM nummod
# ) PUNCT punct
# du ADP case
# 5 NUM nmod
# octobre NOUN nmod
# 1993 NUM nmod
# portant VERB acl
# création NOUN obj
# de ADP case
# la DET det
# Mission NOUN nmod
# des ADP case
# Nations NOUN nmod
# Unies PROPN nmod
# pour ADP case
# l' DET det
# assistance NOUN nmod
# au ADP case
# Rwanda PROPN nmod
# ( PUNCT punct
# MINUAR NOUN appos
# ) PUNCT punct
# , PUNCT punct
# sa DET det
# résolution NOUN nsubj
# 909 NUM obl:mod
# ( PUNCT punct
# 1994 NUM nummod
# ) PUNCT punct
# du ADP case
# 5 NUM nmod
# avril NOUN nmod
# 1994 NUM nmod
# , PUNCT punct
# par ADP case
# laquelle PRON obl:mod
# il PRON nsubj
# a VERB aux:tense
# prorogé VERB ROOT
# le DET det
# mandat NOUN obj
# de ADP case
# la DET det
# MINUAR NOUN nmod
# jusqu' ADP case
# au ADP case
# 29 NUM obl:mod
# juillet NOUN nmod
# 1994 NUM nmod
# et CCONJ cc
# sa DET det
# résolution NOUN conj
# 912 NUM dep
# ( PUNCT punct
# 1994 NUM nummod
# ) PUNCT punct
# du ADP case
# 21 NUM nmod
# avril NOUN nmod
# 1994 NUM nmod
# par ADP case
# laquelle PRON obl:mod
# il PRON nsubj
# a AUX aux:tense
# modifié VERB acl:relcl
# le DET det
# mandat NOUN obj
# de ADP case
# la DET det
# MINUAR PROPN nmod
# , PUNCT punct
#
#  SPACE dep
# Rappelant PROPN xcomp
# les DET det
# déclarations NOUN obj
# faites VERB acl
# par ADP case
# le DET det
# Président NOUN obl:agent
# du ADP case
# Conseil NOUN nmod
# le DET det
# 7 NUM nmod
# avril NOUN nmod
# 1994 NUM nmod
# ( PUNCT punct
# S NOUN appos
# / ADP case
# PRST/1994/16 NOUN nmod
# ) PUNCT punct
# et CCONJ cc
# le DET det
# 30 NUM conj
# avril NOUN nmod
# 1994 NUM nmod
# ( PUNCT punct
# S NOUN nmod
# / ADP nmod
# PRST/1994/21 NOUN nmod
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE dep
# Ayant AUX aux:tense
# examiné VERB conj
# le DET det
# rapport NOUN obj
# du ADP case
# Secrétaire NOUN nmod
# général ADJ amod
# en ADP case
# date NOUN obl:mod
# du ADP case
# 13 NUM nmod
# mai NOUN nmod
# 1994 NUM nmod
# ( PUNCT punct
# S/1994/565 PROPN xcomp
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE dep
# Réaffirmant PROPN flat:name
# sa DET det
# résolution NOUN nsubj
# 868 NUM nummod
# ( PUNCT punct
# 1993 NUM nummod
# ) PUNCT punct
# du ADP case
# 29 NUM nmod
# septembre NOUN nmod
# 1993 NUM nmod
# sur ADP case
# la DET det
# sécurité NOUN nmod
# des ADP case
# opérations NOUN nmod
# des ADP case
# Nations PROPN nmod
# Unies PROPN flat:name
# , PUNCT punct
#
#  SPACE dep
# Condamnant ADV advmod
# vigoureusement VERB advmod
# les DET det
# violences NOUN obj
# en ADP case
# cours NOUN obl:mod
# au ADP case
# Rwanda PROPN obl:arg
# et CCONJ cc
# réprouvant VERB conj
# en ADP advmod
# particulier ADJ fixed
# les DET det
# très ADV advmod
# nombreux ADJ amod
# massacres NOUN obj
# de ADP case
# civils NOUN nmod
# qui PRON obl:mod

# %% [markdown]
# ## Russian

# %%
# Loading in Russian Files
start = time()
f = open('data/sixway/russian.100k', 'r') # Reading in Russian File
russian100 = f.read()
print("Data loaded in:", (time()-start), "seconds.")
f.close()

# Creating Smaller Slice to Analyze using SpaCy
russian_samp = russian100[:1000]
# Out:
# Data loaded in: 0.18409109115600586 seconds.

# %%
nlp = spacy.load('ru_core_news_sm')
doc = nlp(russian_samp)
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# РЕЗОЛЮЦИЯ 918 (1994),
# принятая Советом Безопасности на его 3377-м заседании 17 мая 1994 года
# Совет Безопасности,
# подтверждая все свои предыдущие резолюции о ситуации в Руанде, в частности свою резолюцию 872 (1993) от 5 октября 1993 года, в соответствии с которой он учредил Миссию Организации Объединенных Наций по оказанию помощи Руанде (МООНПР), свою резолюцию 909 (1994) от 5 апреля 1994 года, в которой он продлил мандат МООНПР до 29 июля 1994 года, и свою резолюцию 912 (1994) от 21 апреля 1994 года, в соответствии с которой он изменил мандат МООНПР,
# ссылаясь на заявления Председателя, сделанные им от имени Совета Безопасности 7 апреля 1994 года (S/PRST/1994/16) и 30 апреля 1994 года (S/PRST/1994/21),
# рассмотрев доклад Генерального секретаря от 13 мая 1994 года (S/1994/565),
# подтверждая свою резолюцию 868 (1993) от 29 сентября 1993 года о безопасности операций Организации Объединенных Наций,
# решительно осуждая продолжающееся насилие в Руанде и особенно осуждая многочисленные убийства г
# РЕЗОЛЮЦИЯ PROPN nsubj
# 918 NUM appos
# ( PUNCT punct
# 1994 ADJ parataxis
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE ROOT
# принятая VERB ROOT
# Советом PROPN obl:agent
# Безопасности PROPN nmod
# на ADP case
# его DET det
# 3377-м ADJ amod
# заседании NOUN obl
# 17 ADJ nmod
# мая NOUN flat
# 1994 ADJ amod
# года NOUN nmod
#
#  SPACE ROOT
# Совет PROPN nsubj
# Безопасности PROPN nmod
# , PUNCT punct
#
#  SPACE ROOT
# подтверждая VERB acl
# все DET det
# свои DET det
# предыдущие ADJ amod
# резолюции NOUN obj
# о ADP case
# ситуации NOUN nmod
# в ADP case
# Руанде PROPN nmod
# , PUNCT punct
# в ADP discourse
# частности NOUN fixed
# свою DET det
# резолюцию NOUN parataxis
# 872 NUM appos
# ( PUNCT punct
# 1993 ADJ appos
# ) PUNCT punct
# от ADP case
# 5 ADJ nmod
# октября NOUN flat
# 1993 ADJ amod
# года NOUN nmod
# , PUNCT punct
# в ADP case
# соответствии NOUN fixed
# с ADP fixed
# которой PRON obl
# он PRON nsubj
# учредил VERB acl:relcl
# Миссию PROPN obj
# Организации PROPN nmod
# Объединенных VERB amod
# Наций PROPN nmod
# по ADP case
# оказанию NOUN obl
# помощи NOUN nmod
# Руанде PROPN nmod
# ( PUNCT punct
# МООНПР PROPN parataxis
# ) PUNCT punct
# , PUNCT punct
# свою DET det
# резолюцию NOUN obj
# 909 NUM appos
# ( PUNCT punct
# 1994 ADJ appos
# ) PUNCT punct
# от ADP case
# 5 ADJ nmod
# апреля NOUN flat
# 1994 ADJ amod
# года NOUN nmod
# , PUNCT punct
# в ADP case
# которой PRON obl
# он PRON nsubj
# продлил VERB acl:relcl
# мандат NOUN obj
# МООНПР PROPN nmod
# до ADP case
# 29 ADJ obl
# июля NOUN flat
# 1994 ADJ amod
# года NOUN nmod
# , PUNCT punct
# и CCONJ cc
# свою DET det
# резолюцию NOUN conj
# 912 NUM appos
# ( PUNCT punct
# 1994 ADJ appos
# ) PUNCT punct
# от ADP case
# 21 ADJ nmod
# апреля NOUN flat
# 1994 ADJ amod
# года NOUN nmod
# , PUNCT punct
# в ADP case
# соответствии NOUN fixed
# с ADP fixed
# которой PRON obl
# он PRON nsubj
# изменил VERB acl:relcl
# мандат NOUN obj
# МООНПР PROPN nmod
# , PUNCT punct
#
#  SPACE punct
# ссылаясь VERB advcl
# на ADP case
# заявления NOUN obl
# Председателя PROPN nmod
# , PUNCT punct
# сделанные VERB acl
# им PRON iobj
# от ADP case
# имени NOUN obl
# Совета PROPN nmod
# Безопасности PROPN nmod
# 7 ADJ obl
# апреля NOUN flat
# 1994 ADJ amod
# года NOUN nmod
# ( PUNCT punct
# S PROPN parataxis
# / PUNCT punct
# PRST/1994/16 PROPN flat:foreign
# ) PUNCT punct
# и CCONJ cc
# 30 ADJ obl
# апреля NOUN flat
# 1994 ADJ amod
# года NOUN nmod
# ( PUNCT punct
# S PROPN appos
# / PUNCT punct
# PRST/1994/21 PROPN flat:foreign
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE advcl
# рассмотрев VERB xcomp
# доклад NOUN obj
# Генерального ADJ amod
# секретаря NOUN nmod
# от ADP case
# 13 ADJ nmod
# мая NOUN flat
# 1994 ADJ amod
# года NOUN nmod
# ( PUNCT punct
# S/1994/565 PROPN appos
# ) PUNCT punct
# , PUNCT punct
#
#  SPACE ROOT
# подтверждая VERB advcl
# свою DET det
# резолюцию NOUN obj
# 868 NUM appos
# ( PUNCT punct
# 1993 ADJ appos
# ) PUNCT punct
# от ADP case
# 29 ADJ obl
# сентября NOUN flat
# 1993 ADJ amod
# года NOUN nmod
# о ADP case
# безопасности NOUN obl
# операций NOUN nmod
# Организации PROPN nmod
# Объединенных VERB amod
# Наций PROPN nmod
# , PUNCT punct
#
#  SPACE ROOT
# решительно ADV advmod
# осуждая VERB xcomp
# продолжающееся VERB amod
# насилие NOUN obj
# в ADP case
# Руанде PROPN nmod
# и CCONJ cc
# особенно ADV advmod
# осуждая VERB conj
# многочисленные ADJ amod
# убийства NOUN obj
# г NOUN punct

# %% [markdown]
# ## Chinese

# %%
# Loading in Mandarin Files
start = time()
f = open('data/sixway/mandarin.100k', 'r') # Reading in Mandarin File
mandarin100 = f.read()
print("Data loaded in:", (time()-start), "seconds.")
f.close()

# Creating Smaller Slice to Analyze using SpaCy
mandarin_samp = mandarin100[:1000]
# Out:
# Data loaded in: 0.09326887130737305 seconds.

# %%
nlp = spacy.load('zh_core_web_sm')
doc = nlp(mandarin_samp)
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# 第918(1994)号决议
# 1994年5月17日安全理事会第3377次会议通过
# 安全理事会，
# 重申其以往关于卢旺达局势的所有决议，特别是成立联合国卢旺达援助团(联卢援助团)的1993年10月5日第872(1993)号决议，延长联卢援助团任务期限至1994年7月29日的1994年4月5日第909(1994)号决议，以及调整联卢援助团的任务规定的1994年4月21日第912(1994)号决议，
# 回顾安理会主席以安理会名义在1994年4月7日发表的声明(S/PRST/ 1994/16)和在1994年4月30日发表的声明(S/PRST/1994/21)，
# 审议了1994年5月13日秘书长的报告(S/1994/565)，
# 重申其1993年9月29日关于联合国行动安全的第868(1993)号决议，
# 强烈谴责卢旺达境内目前发生的暴乱，特别是谴责在卢旺达境内发生大量残杀平民，以及武装个人在国内一直横行并继续横行而不受惩罚的情况，
# 强调《阿鲁沙和平协定》对和平解决卢旺达境内冲突的重要性，以及所有各方必须再次承诺充分执行这项协定，
# 赞扬非洲统一组织及其机关和坦桑尼亚调解人努力提供外交、政治和人道主义支助，以期执行安理会的有关决议，
# 对不断传来的卢旺达境内发生有计划、普遍、公然违反国际人道主义法行为和其他侵犯生命和财产权利的报告，再次表示震惊，
# 在这方面回顾屠杀一个种族集团的成员以图将该集团整个或部分消灭，构成根据国际法应受惩罚的罪行，
# 促请所有各方立即停止，特别是通过大众媒体，进行任何煽动暴乱或种族仇恨的行为，
# 又回顾安理会曾请秘书长收集有关造成卢旺达和布隆迪两位总统死难悲惨事件的罪责的资料；
# 进一步回顾安理会曾请秘书长建议如何调查冲突期间严重违反国际人道主义法行为的报告，
# 强调迫切需要采取协调的国际行动，以减轻卢旺达人民的苦难，并协助恢复卢旺达境内的和平，在这方面，欣见联合国与非统组织以及该区域各国、特别是阿鲁沙和平进程的调解人合作，
# 希望在这方面扩大联卢援助团的人道主义任务，并强调重视各方对成功全面实施这一任务的支持与合作，
# 重申承诺维护卢旺达的统一和领土完整，
# 认识到卢旺达人民负有民族和解与本国重建的根本责任，
# 深感不安的是冲突造成人民巨大的苦难，并忧虑卢旺达局势的延续对区域内的和平与安全构成威胁，
# A 1. 要求冲突各方立即停止敌对行为，同意停火，并终止席卷卢旺达的盲目暴乱和杀
# 第918 NUM dep
# ( PUNCT punct
# 1994 NOUN dep
# )号 PROPN nsubj
# 决议 VERB dep
#
#  SPACE dep
# 1994年 NOUN compound:nn
# 5月 NOUN compound:nn
# 17日 NOUN nmod:tmod
# 安全 NOUN compound:nn
# 理事会 NOUN compound:nn
# 第3377 NUM nummod
# 次 NUM mark:clf
# 会议 NOUN nsubj
# 通过 VERB ccomp
#
#  SPACE dep
# 安全 NOUN compound:nn
# 理事会 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 重申 VERB conj
# 其 PRON compound:nn
# 以往 NOUN dep
# 关于 ADP case
# 卢旺达 PROPN nmod:assmod
# 局势 NOUN nmod
# 的 PART case
# 所有 DET det
# 决议 NOUN dobj
# ， PUNCT punct
# 特别是 ADV advmod
# 成立 VERB acl
# 联合国 PROPN name
# 卢旺达 PROPN nmod:assmod
# 援助 NOUN compound:nn
# 团( NOUN nsubj
# 联卢 VERB acl
# 援助 NOUN dobj
# 团) NOUN dobj
# 的 PART mark
# 1993年 NOUN dep
# 10月 NOUN dep
# 5日 NOUN dep
# 第872 NUM dep
# ( PUNCT punct
# 1993 NOUN dep
# )号 PROPN nsubj
# 决议 VERB ccomp
# ， PUNCT punct
# 延长 VERB acl
# 联卢 VERB compound:nn
# 援助团 NOUN compound:nn
# 任务 NOUN compound:nn
# 期限 NOUN dobj
# 至 ADP case
# 1994年 NOUN compound:nn
# 7月 NOUN compound:nn
# 29日 NOUN nmod
# 的 PART case
# 1994年 NOUN compound:nn
# 4月 NOUN dep
# 5日 NOUN dep
# 第909 NUM dep
# ( PUNCT punct
# 1994 NOUN dobj
# )号 PROPN nsubj
# 决议 VERB dobj
# ， PUNCT punct
# 以及 CCONJ cc
# 调整 VERB conj
# 联卢 VERB dobj
# 援助团 NOUN dobj
# 的 PART mark
# 任务 NOUN nsubj
# 规定 VERB conj
# 的 PART mark
# 1994年 NOUN compound:nn
# 4月 NOUN compound:nn
# 21日 NOUN dep
# 第912 NUM dep
# ( PUNCT punct
# 1994 NOUN compound:nn
# )号 PROPN nsubj
# 决议 VERB ccomp
# ， PUNCT punct
#
#  SPACE dep
# 回顾 VERB conj
# 安理会 NOUN compound:nn
# 主席 NOUN nsubj
# 以 ADP case
# 安理会 NOUN compound:nn
# 名义 NOUN nmod:prep
# 在 ADP case
# 1994年 NOUN compound:nn
# 4月 NOUN compound:nn
# 7日 NOUN nmod:prep
# 发表 VERB acl
# 的 PART mark
# 声明 NOUN dobj
# (S PUNCT punct
# / PUNCT punct
# PRST PROPN dep
# / PUNCT punct
# 1994 NOUN dep
# / PUNCT punct
# 16 NUM dep
# ) NOUN conj
# 和 CCONJ cc
# 在 ADP case
# 1994年 NOUN compound:nn
# 4月 NOUN compound:nn
# 30日 NOUN nmod:prep
# 发表 VERB acl
# 的 PART mark
# 声明 NOUN dep
# (S PUNCT punct
# / PUNCT punct
# PRST PROPN dep
# / PUNCT punct
# 1994 NOUN dep
# / PUNCT punct
# 21 NUM dep
# ) NUM ROOT
# ， PUNCT punct
#
#  SPACE dep
# 审议 VERB conj
# 了 PART aux:asp
# 1994年 NOUN compound:nn
# 5月 NOUN compound:nn
# 13日 NOUN dep
# 秘书长 NOUN nmod:assmod
# 的 PART case
# 报告 NOUN dobj
# (S PUNCT punct
# / PUNCT punct
# 1994 NOUN dep
# / PUNCT punct
# 565 NUM dep
# ) NOUN ROOT
# ， PUNCT punct
#
#  SPACE dep
# 重申 VERB conj
# 其 PRON compound:nn
# 1993年 NOUN compound:nn
# 9月 NOUN compound:nn
# 29日 NOUN dep
# 关于 ADP case
# 联合国 PROPN nmod:assmod
# 行动 NOUN compound:nn
# 安全 NOUN nmod:assmod
# 的 PART case
# 第868 NUM dep
# ( PUNCT punct
# 1993 NOUN nmod:prep
# )号 PROPN nsubj
# 决议 VERB ccomp
# ， PUNCT punct
#
#  SPACE dep
# 强烈 ADV advmod
# 谴责 VERB conj
# 卢旺达 PROPN nmod:assmod
# 境内 NOUN dobj
# 目前 NOUN nmod:tmod
# 发生 VERB acl
# 的 PART mark
# 暴乱 NOUN dobj
# ， PUNCT punct
# 特别是 ADV advmod
# 谴责 VERB conj
# 在 ADP case
# 卢旺达 PROPN nmod:assmod
# 境内 NOUN nmod:prep
# 发生 VERB ccomp
# 大量 NUM advmod
# 残杀 VERB conj
# 平民 NOUN dobj
# ， PUNCT punct
# 以及 CCONJ cc
# 武装 ADJ compound:nn
# 个人 NOUN nsubj
# 在 ADP case
# 国内 NOUN nmod:prep
# 一直 ADV advmod
# 横行 VERB conj
# 并 CCONJ cc
# 继续 VERB xcomp
# 横行 VERB conj
# 而 ADV aux:prtmod
# 不 ADV neg
# 受 VERB conj
# 惩罚 NOUN dobj
# 的 PART mark
# 情况 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 强调 VERB conj
# 《 PUNCT punct
# 阿鲁沙 PROPN compound:nn
# 和平 NOUN compound:nn
# 协定 NOUN compound:nn
# 》 PUNCT punct
# 对 ADP case
# 和平 ADV advmod
# 解决 VERB acl
# 卢旺达 PROPN nmod:assmod
# 境内 NOUN compound:nn
# 冲突 NOUN dobj
# 的 PART mark
# 重要性 NOUN dep
# ， PUNCT punct
# 以及 CCONJ cc
# 所有 DET det
# 各方 NOUN nsubj
# 必须 VERB aux:modal
# 再次 ADV advmod
# 承诺 VERB ccomp
# 充分 ADV advmod
# 执行 VERB ccomp
# 这项 DET dep
# 协定 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 赞扬 VERB conj
# 非洲 PROPN dep
# 统一 NOUN compound:nn
# 组织 NOUN conj
# 及其 CCONJ cc
# 机关 NOUN conj
# 和 CCONJ cc
# 坦桑尼亚 PROPN nmod:assmod
# 调解人 NOUN nsubj
# 努力 ADV advmod
# 提供 VERB ccomp
# 外交 NOUN conj
# 、 PUNCT punct
# 政治 NOUN conj
# 和 CCONJ cc
# 人道主义 NOUN compound:nn
# 支助 NOUN dobj
# ， PUNCT punct
# 以 ADP case
# 期 NOUN nmod:prep
# 执行 VERB conj
# 安理会 NOUN nmod:assmod
# 的 PART case
# 有关 ADJ amod
# 决议 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 对 ADP case
# 不断 ADV advmod
# 传来 VERB acl
# 的 PART mark
# 卢旺达 PROPN nmod:assmod
# 境内 NOUN nmod:prep
# 发生 VERB dep
# 有 VERB dep
# 计划 NOUN dobj
# 、 PUNCT punct
# 普遍 ADJ dep
# 、 PUNCT punct
# 公然 ADV advmod
# 违反 VERB conj
# 国际 NOUN compound:nn
# 人道主义 NOUN compound:nn
# 法 NOUN compound:nn
# 行为 NOUN conj
# 和 CCONJ cc
# 其他 DET det
# 侵犯 VERB acl
# 生命 NOUN conj
# 和 CCONJ cc
# 财产 NOUN compound:nn
# 权利 NOUN dobj
# 的 PART mark
# 报告 NOUN dobj
# ， PUNCT punct
# 再次 ADV advmod
# 表示 VERB conj
# 震惊 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 在 ADP case
# 这 DET det
# 方面 NOUN nmod:prep
# 回顾 VERB conj
# 屠杀 NOUN compound:nn
# 一个 NUM dep
# 种族 NOUN compound:nn
# 集团 NOUN nmod:assmod
# 的 PART case
# 成员 NOUN dobj
# 以图 PART advmod
# 将 X aux:ba
# 该 DET det
# 集团 NOUN dep
# 整个 DET conj
# 或 CCONJ cc
# 部分 NUM dep
# 消灭 VERB conj
# ， PUNCT punct
# 构成 VERB conj
# 根据 ADP case
# 国际法 NOUN nsubj
# 应 VERB aux:modal
# 受 VERB acl
# 惩罚 NOUN dobj
# 的 PART mark
# 罪行 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 促请 VERB conj
# 所有 DET det
# 各方 NOUN dobj
# 立即 ADV advmod
# 停止 VERB ccomp
# ， PUNCT punct
# 特别是 ADV advmod
# 通过 ADP case
# 大众 NOUN compound:nn
# 媒体 NOUN nmod:prep
# ， PUNCT punct
# 进行 VERB conj
# 任何 DET det
# 煽动 ADJ amod
# 暴乱 NOUN dobj
# 或 CCONJ cc
# 种族 NOUN compound:nn
# 仇恨 NOUN nmod:assmod
# 的 PART case
# 行为 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 又 ADV advmod
# 回顾 VERB conj
# 安理会 NOUN nsubj
# 曾 ADV advmod
# 请 VERB ccomp
# 秘书长 NOUN dobj
# 收集 VERB ccomp
# 有关 ADP case
# 造成 VERB acl
# 卢旺达 PROPN conj
# 和 CCONJ cc
# 布隆迪 PROPN nmod
# 两 NUM nummod
# 位 NUM mark:clf
# 总统 NOUN nsubj
# 死难 VERB ccomp
# 悲惨 ADJ amod
# 事件 NOUN dobj
# 的 PART mark
# 罪责 NOUN nmod:assmod
# 的 PART case
# 资料 NOUN dobj
# ； PUNCT punct
#
#  SPACE dep
# 进一步 ADV advmod
# 回顾 VERB conj
# 安理会 NOUN nsubj
# 曾 ADV advmod
# 请 VERB acl
# 秘书长 NOUN dobj
# 建议 VERB ccomp
# 如何 ADV advmod
# 调查 VERB ccomp
# 冲突 NOUN dobj
# 期间 NOUN nmod:prep
# 严重 ADV advmod
# 违反 VERB ccomp
# 国际 NOUN compound:nn
# 人道主义 NOUN compound:nn
# 法 NOUN compound:nn
# 行为 NOUN nmod:assmod
# 的 PART case
# 报告 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 强调 VERB conj
# 迫切 ADV advmod
# 需要 VERB xcomp
# 采取 VERB ccomp
# 协调 NOUN nmod:assmod
# 的 PART case
# 国际 NOUN compound:nn
# 行动 NOUN dobj
# ， PUNCT punct
# 以 PART aux:prtmod
# 减轻 VERB conj
# 卢旺达 PROPN nmod:assmod
# 人民 NOUN nmod:assmod
# 的 PART case
# 苦难 NOUN dobj
# ， PUNCT punct
# 并 CCONJ cc
# 协助 VERB conj
# 恢复 VERB ccomp
# 卢旺达 PROPN nmod:assmod
# 境内 NOUN nmod:assmod
# 的 PART case
# 和平 NOUN dobj
# ， PUNCT punct
# 在 ADP case
# 这 DET det
# 方面 NOUN nmod:prep
# ， PUNCT punct
# 欣见 VERB conj
# 联合国 PROPN conj
# 与 CCONJ cc
# 非统 PROPN compound:nn
# 组织 NOUN conj
# 以及 CCONJ cc
# 该 DET det
# 区域 NOUN compound:nn
# 各国 NOUN conj
# 、 PUNCT punct
# 特别是 ADV advmod
# 阿鲁沙 PROPN compound:nn
# 和平 NOUN compound:nn
# 进程 NOUN nmod:assmod
# 的 PART case
# 调解人 NOUN compound:nn
# 合作 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 希望 VERB conj
# 在 ADP case
# 这 DET det
# 方面 NOUN nmod:prep
# 扩大 VERB ccomp
# 联卢 VERB acl
# 援助团 NOUN dobj
# 的 PART mark
# 人道主义 NOUN compound:nn
# 任务 NOUN dobj
# ， PUNCT punct
# 并 CCONJ advmod
# 强调 VERB conj
# 重视 VERB ccomp
# 各方 NOUN dobj
# 对 ADP case
# 成功 ADV advmod
# 全面 ADV advmod
# 实施 VERB ccomp
# 这 DET det
# 一 NUM dep
# 任务 NOUN nmod:assmod
# 的 PART case
# 支持 NOUN conj
# 与 CCONJ cc
# 合作 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 重申 VERB conj
# 承诺 VERB ccomp
# 维护 VERB ccomp
# 卢旺达 PROPN nmod:assmod
# 的 PART case
# 统一 NOUN conj
# 和 CCONJ cc
# 领土 NOUN compound:nn
# 完整 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 认识 VERB conj
# 到 VERB advmod:rcomp
# 卢旺达 PROPN nmod:assmod
# 人民 NOUN nsubj
# 负有 VERB acl
# 民族 NOUN compound:nn
# 和解 NOUN conj
# 与 CCONJ cc
# 本国 NOUN compound:nn
# 重建 NOUN nmod:assmod
# 的 PART case
# 根本 ADJ amod
# 责任 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# 深感 VERB nsubj
# 不安 NOUN dobj
# 的 PART mark
# 是 VERB cop
# 冲突 NOUN nsubj
# 造成 VERB conj
# 人民 NOUN compound:nn
# 巨大 VERB amod
# 的 PART case
# 苦难 NOUN dobj
# ， PUNCT punct
# 并 ADV advmod
# 忧虑 VERB conj
# 卢旺达 PROPN nmod:assmod
# 局势 NOUN nmod:assmod
# 的 PART case
# 延续 NOUN nsubj
# 对 ADP case
# 区域 NOUN nmod
# 内 PART case
# 的 PART case
# 和平 NOUN conj
# 与 CCONJ cc
# 安全 NOUN nmod:prep
# 构成 VERB conj
# 威胁 NOUN dobj
# ， PUNCT punct
#
#  SPACE dep
# A NOUN nsubj
# 1. NUM dep
# 要求 NOUN dep
# 冲突 NOUN compound:nn
# 各方 NOUN dobj
# 立即 ADV advmod
# 停止 VERB ccomp
# 敌对 ADJ amod
# 行为 NOUN dobj
# ， PUNCT punct
# 同意 VERB conj
# 停火 NOUN dobj
# ， PUNCT punct
# 并 ADV advmod
# 终止 VERB conj
# 席卷 VERB ccomp
# 卢旺达 PROPN dobj
# 的 PART case
# 盲目 ADJ amod
# 暴乱 NOUN dobj
# 和 CCONJ cc
# 杀 VERB conj

# %% [markdown]
# ## Arabic

# %%
# Loading in Arabic Files
start = time()
f = open('data/sixway/arabic.100k', 'r') # Reading in Arabic File
arabic100 = f.read()
print("Data loaded in:", (time()-start), "seconds.")
f.close()

# Creating Smaller Slice to Analyze using SpaCy
arabic_samp = arabic100[:1000]
# Out:
# Data loaded in: 0.1610276699066162 seconds.
